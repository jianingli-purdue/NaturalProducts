# %%
# run this when you change utils.py to reload functions from utils.py
# import importlib
# import utils
# importlib.reload(utils)
# Out:
# <module 'utils' from 'C:\\Users\\anton\\PycharmProjects\\small_molecule_viz\\utils.py'>

# %%
from utils import (
    load_data,
    chemical_distance,
    chemical_distances_vs_taxonomic_distances,
    stats_chemical_distances_vs_taxonomic_distances, 
    visualize_chemical_distances_vs_taxonomic_distances, 
    run_all,
    convert_to_array
)

# %% [markdown]
# # Load SELformer embedding

# %%
df_selformer= load_data(
        file_path='magnoliopsida_latent_matrix_SELformer.csv',
        colname_w_smiles='canonical_smiles', # name of the column in the input file, may be not canonicalized smiles
        colname_w_features='latent_vector',   # if features (aka embeddings) are already available in the input file, specify the column name here
        top_rows=None,             # if None, the whole csv file will be loaded, otherwise the given number of top rows will be loaded
        compute_ECFP_fingerprints=False,
)
# Out:
# The size of the dataset 148354, 11199 unique species found
# 1 molecules had non-canonical SMILES, changing them to canonical.

# %%
print(df_selformer['latent_vector'].head())
df_selformer['latent_vector'] = df_selformer['latent_vector'].apply(convert_to_array)
# Out:
# 0    [0.9996867179870605, -0.1381138265132904, -0.2...
# 1    [0.9031962156295776, -0.1396566778421402, -0.2...
# 2    [1.0596888065338135, 0.06600043177604675, -0.3...
# 3    [1.2253227233886719, -0.12660662829875946, -0....
# 4    [1.3149449825286865, -0.17425693571567535, -0....
# Name: latent_vector, dtype: object

# %% [markdown]
# # Load SMILE-Transformer embedding

# %%
df_smitrans= load_data(
        file_path='Lotus_latent_vector_SMILESTRA_Magnoliopsida.csv',
        colname_w_smiles='canonical_smiles', # name of the column in the input file, may be not canonicalized smiles
        colname_w_features='letect_vec_SMILES-TRANSFORMER',   # if features (aka embeddings) are already available in the input file, specify the column name here
        top_rows=None,             # if None, the whole csv file will be loaded, otherwise the given number of top rows will be loaded
        compute_ECFP_fingerprints=False,
)
# Out:
# The size of the dataset 148354, 11199 unique species found
# 1 molecules had non-canonical SMILES, changing them to canonical.

# %%
print(df_smitrans['letect_vec_SMILES-TRANSFORMER'].head())
df_smitrans['letect_vec_SMILES-TRANSFORMER'] = df_smitrans['letect_vec_SMILES-TRANSFORMER'].apply(convert_to_array)
# Out:
# 0    [0.10351907461881638, 0.5218231678009033, -0.1...
# 1    [0.26804080605506897, 0.7653746604919434, 0.11...
# 2    [0.09206713736057281, 0.10572059452533722, 0.2...
# 3    [0.11544938385486603, 0.7165117263793945, -0.0...
# 4    [0.1333526074886322, 0.20717120170593262, 0.24...
# Name: letect_vec_SMILES-TRANSFORMER, dtype: object

# %%
run_all(
        df_smitrans,
        ref_chain=["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Brassicaceae", "Arabidopsis", "Arabidopsis thaliana"],
        max_taxonomic_distance=3,   # 2 for debugging, 3 for production runs
        size_threshold=20,
        encoding_columns='letect_vec_SMILES-TRANSFORMER',
        distance_metric='Euclidean',
        verbose=True,
)
# Out:
# taxonomic_distance: percentile_50_ave (percentile_50_std), percentile_25_ave (percentile_25_std)
# 0: 0.000 (nan), 0.000 (nan)
# 1: nan (nan), nan (nan)
# 2: 7.087 (0.874), 5.630 (0.888)
# 3: 8.075 (1.594), 6.984 (1.473)

# %%
run_all(
        df_smitrans,
        ref_chain=["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Celastraceae", "Tripterygium", "Tripterygium wilfordii"],
        max_taxonomic_distance=3,   # 2 for debugging, 3 for production runs
        size_threshold=20,
        encoding_columns='letect_vec_SMILES-TRANSFORMER',
        distance_metric='Euclidean',
        verbose=True,
)
# Out:
# taxonomic_distance: percentile_50_ave (percentile_50_std), percentile_25_ave (percentile_25_std)
# 0: 0.000 (nan), 0.000 (nan)
# 1: 3.598 (0.387), 2.559 (0.203)
# 2: 4.235 (0.981), 3.162 (0.506)
# 3: 7.573 (2.018), 6.391 (1.843)

# %%
run_all(
        df_smitrans,
        ref_chain=["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Meliaceae", "Azadirachta", "Azadirachta indica"],
        max_taxonomic_distance=3,   # 2 for debugging, 3 for production runs
        size_threshold=20,
        encoding_columns='letect_vec_SMILES-TRANSFORMER',
        distance_metric='Euclidean',
        verbose=True,
)
# Out:
# taxonomic_distance: percentile_50_ave (percentile_50_std), percentile_25_ave (percentile_25_std)
# 0: 0.000 (nan), 0.000 (nan)
# 1: nan (nan), nan (nan)
# 2: 5.518 (1.628), 4.444 (1.288)
# 3: 7.485 (1.855), 6.339 (1.659)

# %% [markdown]
# # Load Chemformer embedding

# %%
df_chemformer= load_data(
        file_path='magnoliopsida_latent_matrix_Chemformer.csv',
        colname_w_smiles='canonical_smiles', # name of the column in the input file, may be not canonicalized smiles
        colname_w_features='latent_vector',   # if features (aka embeddings) are already available in the input file, specify the column name here
        top_rows=None,             # if None, the whole csv file will be loaded, otherwise the given number of top rows will be loaded
        compute_ECFP_fingerprints=False,
)
# Out:
# The size of the dataset 148354, 11199 unique species found
# 1 molecules had non-canonical SMILES, changing them to canonical.

# %%
print(df_chemformer['latent_vector'].head())
df_chemformer['latent_vector'] = df_chemformer['latent_vector'].apply(convert_to_array)
# Out:
# 0    [-0.108082004, 0.14120933, -0.024545254, -0.13...
# 1    [-0.2997553, 0.269948, -0.09004489, 0.05555617...
# 2    [-0.15396392, 0.2831985, -0.13380378, -0.04120...
# 3    [-0.22701508, 0.05883386, -0.030429918, -0.256...
# 4    [-0.066330306, 0.10400024, -0.11059299, -0.187...
# Name: latent_vector, dtype: object

# %%
run_all(
        df_chemformer,
        ref_chain=["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Brassicaceae", "Arabidopsis", "Arabidopsis thaliana"],
        max_taxonomic_distance=3,   # 2 for debugging, 3 for production runs
        size_threshold=20,
        encoding_columns='latent_vector',
        distance_metric='Euclidean',
        verbose=True,
)
# Out:
# taxonomic_distance: percentile_50_ave (percentile_50_std), percentile_25_ave (percentile_25_std)
# 0: 0.000 (nan), 0.000 (nan)
# 1: nan (nan), nan (nan)
# 2: 2.208 (0.276), 1.619 (0.375)
# 3: 2.577 (0.394), 2.288 (0.417)

# %%
run_all(
        df_chemformer,
        ref_chain=["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Celastraceae", "Tripterygium", "Tripterygium wilfordii"],
        max_taxonomic_distance=3,   # 2 for debugging, 3 for production runs
        size_threshold=20,
        encoding_columns='latent_vector',
        distance_metric='Euclidean',
        verbose=True,
)
# Out:
# taxonomic_distance: percentile_50_ave (percentile_50_std), percentile_25_ave (percentile_25_std)
# 0: 0.000 (nan), 0.000 (nan)
# 1: 1.008 (0.394), 0.574 (0.346)
# 2: 1.373 (0.364), 1.024 (0.234)
# 3: 2.570 (0.543), 2.302 (0.511)

# %% [markdown]
# # Compute Welch statistics for various species

# %%
for distance_metric in ['Euclidean', 'Cosine']:
    print(distance_metric)
    for ref_chain in [
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Celastraceae", "Tripterygium", "Tripterygium wilfordii"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Meliaceae", "Melia", "Melia azedarach"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Brassicaceae", "Arabidopsis", "Arabidopsis thaliana"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Meliaceae", "Azadirachta", "Azadirachta indica"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Theaceae", "Camellia", "Camellia sinensis"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Araliaceae", "Panax", "Panax ginseng"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Cucurbitaceae", "Momordica", "Momordica charantia"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Simaroubaceae", "Brucea", "Brucea javanica"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Solanaceae", "Nicotiana", "Nicotiana tabacum"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Solanaceae", "Withania", "Withania somnifera"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Cucurbitaceae", "Gynostemma", "Gynostemma pentaphyllum"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Schisandraceae", "Kadsura", "Kadsura coccinea"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Annonaceae", "Annona", "Annona muricata"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Vitaceae", "Vitis", "Vitis vinifera"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Meliaceae", "Xylocarpus", "Xylocarpus granatum"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Annonaceae", "Annona", "Annona squamosa"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Cannabaceae", "Cannabis", "Cannabis sativa"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Zingiberaceae", "Zingiber", "Zingiber officinale"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Rutaceae", "Clausena", "Clausena excavata"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Araliaceae", "Panax", "Panax notoginseng"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Lamiaceae", "Isodon", "Isodon rubescens"],
        ["Eukaryota", "Viridiplantae", "Streptophyta", "Magnoliopsida", "Simaroubaceae", "Eurycoma", "Eurycoma longifolia"],
    ]:
        print("chemformer")
        o = run_all(df_chemformer, ref_chain=ref_chain, max_taxonomic_distance=3, encoding_columns='latent_vector', distance_metric=distance_metric, verbose=False, visualize=False, save_dataframes_to_folder="C:/Users/anton/Desktop/c/JianingLi/results_comparison_embeddings/chemformer")
        print(o.to_string())
        
        print("selformer")
        o = run_all(df_selformer, ref_chain=ref_chain, max_taxonomic_distance=3, encoding_columns='latent_vector', distance_metric=distance_metric, verbose=False, visualize=False, save_dataframes_to_folder="C:/Users/anton/Desktop/c/JianingLi/results_comparison_embeddings/selformer")
        print(o.to_string())

        print("smitrans")
        o = run_all(df_smitrans, ref_chain=ref_chain, max_taxonomic_distance=3, encoding_columns='letect_vec_SMILES-TRANSFORMER', distance_metric=distance_metric, verbose=False, visualize=False, save_dataframes_to_folder="C:/Users/anton/Desktop/c/JianingLi/results_comparison_embeddings/smitrans")
        print(o.to_string())

    print()
# Out:
# Euclidean
# chemformer
#                                                                                    taxonomic_chain_ref  Wtstat_25  Wt_pvalue_25   Wtdof_25  Wtstat_50  Wt_pvalue_50   Wtdof_50
# 0  Eukaryota-Viridiplantae-Streptophyta-Magnoliopsida-Celastraceae-Tripterygium-Tripterygium wilfordii  27.486322  1.611482e-22  29.391304  16.819606  5.047415e-16  27.562343
# selformer
#                                                                                    taxonomic_chain_ref  Wtstat_25  Wt_pvalue_25   Wtdof_25  Wtstat_50  Wt_pvalue_50   Wtdof_50
# 0  Eukaryota-Viridiplantae-Streptophyta-Magnoliopsida-Celastraceae-Tripterygium-Tripterygium wilfordii   9.661346  3.094102e-10  26.879606  10.212423  6.998430e-11  27.629822
# smitrans
#                                                                                    taxonomic_chain_ref  Wtstat_25  Wt_pvalue_25   Wtdof_25  Wtstat_50  Wt_pvalue_50   Wtdof_50
# ...
